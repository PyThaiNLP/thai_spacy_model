# %%
import spacy

# %%
nlp = spacy.load("./spacy.word2vec.model")

# %%
doc = nlp("แมวกินปลาทู")

# %%
list(doc)
# Out:
# [แมว, กิน, ปลาทู]

# %%
doc.vector
# Out:
# array([-0.03383967,  0.01892867,  0.10732701, -0.01690633, -0.05376534,
#         0.20563133,  0.152701  , -0.15625001, -0.09117533, -0.124744  ,
#        -0.145423  ,  0.02132433,  0.10005166,  0.141846  , -0.021057  ,
#        -0.10209034,  0.01352933, -0.13219267, -0.12390434,  0.07472333,
#         0.007499  ,  0.0564    , -0.028176  ,  0.02780033, -0.17576267,
#        -0.01002867, -0.08064333,  0.11666533,  0.37131134, -0.19659501,
#         0.18403967, -0.08678833,  0.10807133, -0.34128833,  0.156486  ,
#         0.06902667, -0.107329  , -0.03559734, -0.08212933,  0.12584932,
#        -0.088142  , -0.008268  , -0.139661  , -0.208439  ,  0.08793234,
#         0.17423   ,  0.05475399, -0.144723  ,  0.03573934,  0.16137534,
#        -0.21411799, -0.09242334, -0.13092567,  0.12756133, -0.112256  ,
#         0.08052834, -0.22300135, -0.036205  ,  0.128022  , -0.18457766,
#         0.043259  , -0.00322267, -0.008264  , -0.03207467,  0.036044  ,
# ...
